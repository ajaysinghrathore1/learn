# %%
from groq import Groq
import os 

GROQ_API_KEY = os.environ.get("GROQ_API_KEY")

groq_model ="openai/gpt-oss-120b"  # or "groq/groq-llama2-70b" or "groq/groq-llama3-70b"
client = Groq(api_key=GROQ_API_KEY)



chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "How do airplanes fly? Be concise."
        }
    ],
    model=groq_model,
    stream=False,
    include_reasoning=False
)

print(chat_completion.choices[0].message.content)
# Out:
# Airplanes stay aloft by generating **lift** faster than gravity pulls them down.
#
# 1. **Airfoil shape**: Wings are curved on top and flatter on the bottom. As the plane moves forward, air must travel a longer path over the top, speeding up and creating lower pressure there (Bernoulli principle).
# 2. **Angle of attack**: Tilting the wing slightly forces air downwards, and by Newton’s third law the wing is pushed upward.
# 3. **Lift = pressure difference × wing area** → upward force that overcomes weight.
#
# Meanwhile **thrust** from engines pushes the plane forward, overcoming **drag** (air resistance). When thrust > drag and lift > weight, the airplane climbs, cruises, or descends as the pilot adjusts speed, wing angle, and control surfaces.

# %%
# pip install langchain-groq
# https://console.groq.com/docs/quickstart
